# %%
from functions_from_rust_4_kivy import get_family_data_from_db
for i in get_family_data_from_db(14):
    print(i)
# Out:
# ('Jainu Jacob', 'Jainu Jacob, Sabitha Jainu, Jerusha Susan Jacob, Jenessa Maria Jacob, Jerome jainu Jacob')
# ('Regi Kurian ', 'Regi Kurian , Anitha John , Joanna Elizabeth Regi ')
# ('Jijo Varghese', 'Jijo Varghese, Jimsy K John')
# ('Ken Abraham ', 'Ken Abraham , Divya')
# ('Ashish Philip Zachariah', 'Ashish Philip Zachariah, Madona Stephen, Sarah Miriam Zachariah')
# ('Joby George', 'Joby George, Sherry Joby, Justina')
# ('Shijin Titus', 'Shijin Titus, Susan Varghese, Aida Shijin ')
# ('Celeena Joy(w/o Late Mr. Y Joy) ', 'Celeena Joy(w/o Late Mr. Y Joy) , Jerome Joy')
# ('Roby yohannan', 'Roby yohannan, Beena Roby, Reeba Roby, Joshua Roby')
# ('Joseph George', 'Joseph George, Mariyamma Joseph, Nimi Ann Joseph')
# ('Shiji V Skariah', 'Shiji V Skariah, Jini Shiji, Emmanuel S, Emily S')
# ('Jiby Sebastian', 'Jiby Sebastian, Jincy Jiby, Harold Sebastian Jose, Hebin Joseph')
# ('Rajesh P Koshy', 'Rajesh P Koshy, Jisha Rajesh , Rheanna Rajesh, Evanna Rajesh, Annamma Koshy')
# ...

# %%
get_family_data_from_db(0)
# Out:
# [('Jainu Jacob',
#   'Jainu Jacob, Sabitha Jainu, Jerusha Susan Jacob, Jenessa Maria Jacob, Jerome jainu Jacob'),
#  ('Regi Kurian ', 'Regi Kurian , Anitha John , Joanna Elizabeth Regi '),
#  ('Jijo Varghese', 'Jijo Varghese, Jimsy K John'),
#  ('Ken Abraham ', 'Ken Abraham , Divya'),
#  ('Ashish Philip Zachariah',
#   'Ashish Philip Zachariah, Madona Stephen, Sarah Miriam Zachariah'),
#  ('Joby George', 'Joby George, Sherry Joby, Justina'),
#  ('Shijin Titus', 'Shijin Titus, Susan Varghese, Aida Shijin '),
#  ('Celeena Joy(w/o Late Mr. Y Joy) ',
#   'Celeena Joy(w/o Late Mr. Y Joy) , Jerome Joy'),
#  ('Roby yohannan', 'Roby yohannan, Beena Roby, Reeba Roby, Joshua Roby'),
#  ('Joseph George', 'Joseph George, Mariyamma Joseph, Nimi Ann Joseph'),
#  ('Shiji V Skariah', 'Shiji V Skariah, Jini Shiji, Emmanuel S, Emily S'),
#  ('Jiby Sebastian',
#   'Jiby Sebastian, Jincy Jiby, Harold Sebastian Jose, Hebin Joseph'),
#  ('Rajesh P Koshy',
# ...

# %%
get_family_data_from_db(0).append
# Out:
# <function list.append(object, /)>
